# %%
price = int(input("税抜価格を入力してください: "))
tax_included = price * 1.1

if tax_included >= 2000:
    print("送料は無料です")
    print(f"送料込税込価格は{tax_included}円です")
else:
    print("送料は350円です")
    print(f"送料込税込価格は{tax_included + 350}円です")
# Out:
# 送料は350円です
# 送料込税込価格は2330.0円です
