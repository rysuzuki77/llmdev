# %%
principal = int(input("元金を入力してください: "))
print(f"元金を入力してください：{principal}")
apr = int(input("年利を入力してください: "))
print(f"年利を入力してください:：{apr}")

for i in range(10):
    principal = principal * (1 + apr/100)

print(f"10年後の金額：{principal}")
# Out:
# 元金を入力してください：1000
# 年利を入力してください:：5
# 10年後の金額：1628.8946267774422
