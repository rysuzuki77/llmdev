# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_b462529f83e44353948965ead11ad4fc',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に使うためのポイントはいくつかあります。以下に主なポイントを挙げます。\n\n1. **明確な目的を持つ**: モデルを使う目的を明確に定義することが重要です。情報収集、文章生成、アイデアのブレインストーミングなど、用途によってアプローチが異なります。\n\n2. **具体的な指示**: 明確で具体的な指示や質問を与えることが、より正確で有用な応答を引き出す鍵です。曖昧な問いは曖昧な回答を生む可能性があります。\n\n3. **文脈を提供する**: モデルが理解しやすいように、関連する情報や背景を提供することが大切です。特に専門的な内容や特定の状況について話す場合は、文脈を与えることで応答の質が向上します。\n\n4. **結果の確認とフィルタリング**: 提供された情報を鵜呑みにせず、正確性や信頼性を確認することが重要です。特に批判的な意見や重要な決定を要する場合は、他の情報源と照らし合わせるべきです。\n\n5. **クリエイティブな利用**: 言語モデルは想像力を刺激するツールとしても使えます。アイデア出しやストーリー作成など、創造的なプロセスをサポートするために活用できます。\n\n6. **反復と調整**: 初めのプロンプトがうまくいかない場合は、質問や指示を調整して再試行することが効果的です。少しの変更で結果が大きく変わることがあります。\n\n7. **倫理的な利用**: 用途に応じた倫理的な考慮を怠らないことが重要です。不適切な情報の生成や誤解を招く内容を避けるために注意を払いましょう。\n\nこれらのポイントを考慮することで、言語モデルをより効果的に活用できるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1771776268,
#  'id': 'chatcmpl-DC6EWvoEDpBKtJARICpcqjf7PauKq',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_084a28d6e8',
#  'usage': CompletionUsage(completion_tokens=504, prompt_tokens=18, total_tokens=522, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確な目的を持つ**: モデルを使う目的を明確に定義することが重要です。情報収集、文章生成、アイデアのブレインストーミングなど、用途によってアプローチが異なります。
#
# 2. **具体的な指示**: 明確で具体的な指示や質問を与えることが、より正確で有用な応答を引き出す鍵です。曖昧な問いは曖昧な回答を生む可能性があります。
#
# 3. **文脈を提供する**: モデルが理解しやすいように、関連する情報や背景を提供することが大切です。特に専門的な内容や特定の状況について話す場合は、文脈を与えることで応答の質が向上します。
#
# 4. **結果の確認とフィルタリング**: 提供された情報を鵜呑みにせず、正確性や信頼性を確認することが重要です。特に批判的な意見や重要な決定を要する場合は、他の情報源と照らし合わせるべきです。
#
# 5. **クリエイティブな利用**: 言語モデルは想像力を刺激するツールとしても使えます。アイデア出しやストーリー作成など、創造的なプロセスをサポートするために活用できます。
#
# 6. **反復と調整**: 初めのプロンプトがうまくいかない場合は、質問や指示を調整して再試行することが効果的です。少しの変更で結果が大きく変わることがあります。
#
# 7. **倫理的な利用**: 用途に応じた倫理的な考慮を怠らないことが重要です。不適切な情報の生成や誤解を招く内容を避けるために注意を払いましょう。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用できるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略には、以下のステップが含まれます。これらを組み合わせることで、製品の認知度を高め、顧客の興味を引き、販売促進につなげることができます。
#
# ### 1. 市場調査
# - **ターゲットセグメントの特定**: 誰が製品を購入するのか、その属性やニーズを明確にします。
# - **競合分析**: 同じ市場における競合製品の強みや弱みを把握し、自社製品の差別化要素を見つけます。
#
# ### 2. ブランドストーリーの構築
# - **製品のユニークバリュー**: 顧客にとっての製品の価値や、解決する問題を明確にします。
# - **ストーリーを伝える**: 製品の開発背景や理念を含めたストーリーを作り、感情に訴えるマーケティングにします。
#
# ### 3. プロモーション戦略
# - **プレスリリース**: 新製品の発売を告知するプレスリリースを作成し、メディアや業界関係者に配信します。
# - **ソーシャルメディアキャンペーン**: 顧客とのインタラクションを促進し、バイラル効果を狙ったコンテンツを制作・配信します。
#
# ### 4. イントロダクションイベント
# - **製品発表会**: オンラインまたはオフラインで新製品のローンチイベントを開催し、メディアやインフルエンサーを招待します。
# - **体験会・デモンストレーション**: 直接製品を体験できる機会を提供し、フィードバックを得る場とします。
#
# ### 5. インフルエンサーマーケティング
# - **影響力のあるインフルエンサーとのコラボレーション**: 彼らのフォロワーに製品の魅力を伝えてもらい、信頼性を高めます。
#
# ### 6. デジタルマーケティング
# - **SEO対策**: 製品に関連するキーワードでの検索エンジン最適化を行い、オーガニックトラフィックを増やします。
# - **広告出稿**: Google広告やSNS広告を利用して、ターゲット層にリーチします。
#
# ### 7. 顧客フィードバックの収集
# - **テストマーケティング**: 限定的な市場で製品をテスト販売し、顧客の反応を測定します。
# - **レビューやアンケート**: 早期の購入者からのフィードバックを基に、製品やマーケティング戦略の改善につなげます。
#
# ### 8. アフターケア戦略
# - **顧客サポート**: 購入後のフォローアップやカスタマーサポート体制を強化し、リピーターの獲得を目指します。
# - **ロイヤルティプログラム**: 定期的な購入を促進するためのインセンティブを提供します。
#
# これらのステップをしっかりと計画・実行することで、新製品の成功につなげることができるでしょう。需要に応じて戦略を調整し、柔軟に対応することも重要です。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には美しい風景や豊かな文化、そして祭りや食など、音と色であふれた多くの魅力があります。いくつか具体的なポイントを挙げますね。
#
# ### 1. 四季の美
# 日本は四季がはっきりしており、それぞれの季節に特徴があります。春には桜が咲き誇り、夏には祭りや花
# --------------------
# もちろんです！日本は多様な魅力にあふれた国です。以下はそのいくつかをご紹介します。
#
# ### 1. 文化と伝統
# - **寺社の様式**: 京都や奈良には美しい寺社が数多くあり、歴史的な建築物や風景が楽しめます。
# - **茶道**: 日本独自の茶道文化は、抹茶を用いた優
# --------------------
# 日本の魅力は多岐にわたります。以下にいくつかのポイントを挙げてみます。
#
# 1. **自然の美**: 日本は四季の変化が鮮明で、それぞれの季節に素晴らしい風景を楽しめます。春の桜、夏の緑陰、秋の紅葉、冬の雪景色など、いずれも美しい光景です。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本は多様な魅力を持つ国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と歴史
# 日本は古い歴史を持ち、伝統と現代が共存しています。神社や寺、古い城などの歴史的な建造物が多くあり、特に京都や奈良は歴史愛好者にとっての聖地です。
#
# ###
# --------------------
# もちろんです！日本は非常に魅力的な国で、多様な文化、自然、歴史、料理、そして人々があります。以下にいくつかの日本の魅力を紹介します。
#
# ### 1. 文化と伝統
# 日本は古くからの伝統と現代的な文化が共存しています。お祭り、茶道、書道、そして伝統的な日本の服装である着物は、歴
# --------------------
# もちろんです！日本には魅力がたくさんあります。以下にいくつかのポイントを紹介します。
#
# ### 1. 伝統文化
# 日本の伝統文化は非常に多様です。茶道、華道、書道、歌舞伎、能、着物など、古くからの文化が大切に受け継がれています。特に、季節ごとの行事や祭りは、地域ごと

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは、Aさん！最近どうですか？
# --------------------
# B:こんにちは、Aさん！お元気ですか？
# --------------------
# B:こんにちは！Aさん、元気ですか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に活用するためのポイントはいくつかあります。以下に主なものを挙げます。
#
# 1. **目的を明確にする**: 何を達成したいのかを明確にすることが重要です。質問応答、文章生成、要約など、モデルを使う目的によって活用方法が異なります。
#
# 2. **適切なプロンプトを設計する**: モデルに与える指示や質問（プロンプト）は、出力に大きな影響を与えます。具体的で明確なプロンプトを作成することで、より正確な応答を得られる可能性が高まります。
#
# 3. **コンテキストを提供する**: モデルは過去の文脈を考慮することができるため、必要に応じて関連情報や背景を提供することで、より適切な応答を引き出すことができます。
#
# 4. **フィードバックと修正**: 得られた結果を基に、プロンプトを調整することが重要です。初回の結果が期待通りでない場合は、プロンプトを改善して再試行してみることが有効です。
#
# 5. **バイアスや制約を理解する**: 言語モデルはトレーニングデータに基づいているため、バイアスや誤情報が含まれている可能性があります。結果を鵜呑みにせず、批判的に検討する姿勢が重要です。
#
# 6. **用途を考慮する**: 法律、医学、倫理に関わる重要な決定には慎重になるべきです。モデルは情報を提供できますが、専門家の判断に代わるものではありません。
#
# 7. **プライバシーを守る**: 個人情報や機密情報をモデルに入力しないようにしましょう。プライバシーやセキュリティに配慮することが重要です。
#
# 8. **連携を考える**: 他のツールやシステムと組み合わせて使用することで、言語モデルの効果を高めることが可能です。たとえば、データベースとの連携や分析ツールとの統合などが考えられます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができるでしょう。
